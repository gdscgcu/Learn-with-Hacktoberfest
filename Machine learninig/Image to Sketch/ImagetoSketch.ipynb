# %% [markdown]
# # ImagetoSketch

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image.
# This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image.
# Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image.
# This can be done by dividing the grayscale image by the inverted blurry image.
# Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %%
import numpy as np
import cv2 as cv
from skimage import io
from skimage import util

# %%
img = io.imread('apple.jpg')
img.shape
# Out:
# (512, 512, 3)

# %%
io.imshow(img)

# %% [markdown]
# ***Converting image to RGB format***

# %%
rgb_img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
io.imshow(rgb_img)

# %% [markdown]
# ***Converting image to grayscale***

# %%
gray_img = cv.cvtColor(rgb_img, cv.COLOR_BGR2GRAY)

# %%
io.imshow(gray_img)

# %% [markdown]
# ***Invering the image***

# %%
inverted_img = util.invert(gray_img)

# %%
io.imshow(inverted_img)

# %% [markdown]
# ***Converting image to Blur image***

# %%
blur_img = cv.GaussianBlur(inverted_img, (111,111),0)

# %%
io.imshow(blur_img)

# %% [markdown]
# ***Invering the blured image***

# %%
inverted_blurimg = util.invert(blur_img)

# %%
io.imshow(inverted_blurimg)

# %% [markdown]
# ***Finaly converting image to sketch***

# %%
sketch_img=cv.divide(gray_img,inverted_blurimg, scale=256.0)

# %%
io.imshow(sketch_img)
